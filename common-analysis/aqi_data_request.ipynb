# %%
import os 
from dotenv import load_dotenv
import json, time
import requests
import pandas as pd

# %%
load_dotenv()  # Loads the .env file

USERNAME = os.getenv('EMAIL')
APIKEY = os.getenv('APIKEY')

# %%
#########
#
#    CONSTANTS
#

#
#    This is the root of all AQS API URLs
#
API_REQUEST_URL = 'https://aqs.epa.gov/data/api'

#
#    These are some of the 'actions' we can ask the API to take or requests that we can make of the API
#
#    Sign-up request - generally only performed once - unless you lose your key
API_ACTION_SIGNUP = '/signup?email={email}'
#
#    List actions provide information on API parameter values that are required by some other actions/requests
API_ACTION_LIST_CLASSES = '/list/classes?email={email}&key={key}'
API_ACTION_LIST_PARAMS = '/list/parametersByClass?email={email}&key={key}&pc={pclass}'
API_ACTION_LIST_SITES = '/list/sitesByCounty?email={email}&key={key}&state={state}&county={county}'
#
#    Monitor actions are requests for monitoring stations that meet specific criteria
API_ACTION_MONITORS_COUNTY = '/monitors/byCounty?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&state={state}&county={county}'
API_ACTION_MONITORS_BOX = '/monitors/byBox?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&minlat={minlat}&maxlat={maxlat}&minlon={minlon}&maxlon={maxlon}'
#
#    Summary actions are requests for summary data. These are for daily summaries
API_ACTION_DAILY_SUMMARY_COUNTY = '/dailyData/byCounty?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&state={state}&county={county}'
API_ACTION_DAILY_SUMMARY_BOX = '/dailyData/byBox?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&minlat={minlat}&maxlat={maxlat}&minlon={minlon}&maxlon={maxlon}'
#
#    It is always nice to be respectful of a free data resource.
#    We're going to observe a 100 requests per minute limit - which is fairly nice
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED
#
#
#    This is a template that covers most of the parameters for the actions we might take, from the set of actions
#    above. In the examples below, most of the time parameters can either be supplied as individual values to a
#    function - or they can be set in a copy of the template and passed in with the template.
# 
AQS_REQUEST_TEMPLATE = {
    "email":      "",     
    "key":        "",      
    "state":      "",     # the two digit state FIPS # as a string
    "county":     "",     # the three digit county FIPS # as a string
    "begin_date": "",     # the start of a time window in YYYYMMDD format
    "end_date":   "",     # the end of a time window in YYYYMMDD format, begin_date and end_date must be in the same year
    "minlat":    0.0,
    "maxlat":    0.0,
    "minlon":    0.0,
    "maxlon":    0.0,
    "param":     "",     # a list of comma separated 5 digit codes, max 5 codes requested
    "pclass":    ""      # parameter class is only used by the List calls
}

#
#   Once we have a list of the classes or groups of possible sensors, we can find the sensor IDs that make up that class (group)
#   The one that looks to be associated with the Air Quality Index is "AQI POLLUTANTS"
#   We'll use that to make another list request.
#
AQI_PARAM_CLASS = "AQI POLLUTANTS"
#
#   Given the set of sensor codes, now we can create a parameter list or 'param' value as defined by the AQS API spec.
#   It turns out that we want all of these measures for AQI, but we need to have two different param constants to get
#   all seven of the code types. We can only have a max of 5 sensors/values request per param.
#
#   Gaseous AQI pollutants CO, SO2, NO2, and O2
AQI_PARAMS_GASEOUS = "42101,42401,42602,44201"
#
#   Particulate AQI pollutants PM10, PM2.5, and Acceptable PM2.5
AQI_PARAMS_PARTICULATES = "81102,88101,88502"
#   
#

# We want to pull from 1961 to 2021
STARTYEAR = 1961
ENDYEAR = 2021

# %%
CITY_LOCATIONS = {
    'birmingham' :       {'city'   : 'Birmingham',
                       'county' : 'Jefferson',
                       'state'  : 'Alabama',
                       'fips'   : '01073',
                       'latlon' : [33.53, -86.80] }, 
}

# %%
#
#   These are rough estimates for creating bounding boxes based on a city location
#   You can find these rough estimates on the USGS website:
#   https://www.usgs.gov/faqs/how-much-distance-does-a-degree-minute-and-second-cover-your-maps
#
LAT_25MILES = 25.0 * (1.0/69.0)    # This is about 25 miles of latitude in decimal degrees
LON_25MILES = 25.0 * (1.0/54.6)    # This is about 25 miles of longitude in decimal degrees
#
#   Compute rough estimates for a bounding box around a given place
#   The bounding box is scaled in 50 mile increments. That is, the bounding box will have sides that
#   are rough multiples of 50 miles, with the center of the box around the indicated place.
#   The scale parameter determines the scale (size) of the bounding box
#
def bounding_latlon(place=None,scale=1.0):
    minlat = place['latlon'][0] - float(scale) * LAT_25MILES
    maxlat = place['latlon'][0] + float(scale) * LAT_25MILES
    minlon = place['latlon'][1] - float(scale) * LON_25MILES
    maxlon = place['latlon'][1] + float(scale) * LON_25MILES
    return [minlat,maxlat,minlon,maxlon]

# %%
#
#    This implements the monitors request. This requests monitoring stations. This can be done by state, county, or bounding box. 
#
#    Like the two other functions, this can be called with a mixture of a defined parameter dictionary, or with function
#    parameters. If function parameters are provided, those take precedence over any parameters from the request template.
#
def request_monitors(email_address = None, key = None, param=None,
                          begin_date = None, end_date = None, fips = None,
                          endpoint_url = API_REQUEST_URL, 
                          endpoint_action = API_ACTION_MONITORS_COUNTY, 
                          request_template = AQS_REQUEST_TEMPLATE,
                          headers = None):
    
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    if param:
        request_template['param'] = param
    if begin_date:
        request_template['begin_date'] = begin_date
    if end_date:
        request_template['end_date'] = end_date
    if fips and len(fips)==5:
        request_template['state'] = fips[:2]
        request_template['county'] = fips[2:]            

    # Make sure there are values that allow us to make a call - these are always required
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_monitors()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_monitors()'")
    if not request_template['param']: 
        raise Exception("Must supply param values to call 'request_monitors()'")
    if not request_template['begin_date']: 
        raise Exception("Must supply a begin_date to call 'request_monitors()'")
    if not request_template['end_date']: 
        raise Exception("Must supply an end_date to call 'request_monitors()'")
    # Note we're not validating FIPS fields because not all of the monitors actions require the FIPS numbers
    
    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
    
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
#
#    Create a copy of the AQS_REQUEST_TEMPLATE
#
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_PARTICULATES     # same particulate request as the one abover
# 
#   Not going to use these - comment them out
#request_data['state'] = CITY_LOCATIONS['bend']['fips'][:2]
#request_data['county'] = CITY_LOCATIONS['bend']['fips'][2:]
#
#   Now, we need bounding box parameters

#   50 mile box
bbox = bounding_latlon(CITY_LOCATIONS['birmingham'],scale=1.0)
#   100 mile box
#bbox = bounding_latlon(CITY_LOCATIONS['bend'],scale=2.0)
#   150 mile box
#bbox = bounding_latlon(CITY_LOCATIONS['bend'],scale=3.0)
#   200 mile box
#bbox = bounding_latlon(CITY_LOCATIONS['bend'],scale=4.0)

# the bbox response comes back as a list - [minlat,maxlat,minlon,maxlon]

#   put our bounding box into the request_data
request_data['minlat'] = bbox[0]
request_data['maxlat'] = bbox[1]
request_data['minlon'] = bbox[2]
request_data['maxlon'] = bbox[3]

#
#   we need to change the action for the API from the default to the bounding box - same recent date for now
response = request_monitors(request_template=request_data, begin_date="20210701", end_date="20210731",
                            endpoint_action = API_ACTION_MONITORS_BOX)
#
#
#
if response["Header"][0]['status'] == "Success":
    print(json.dumps(response['Data'],indent=4))
else:
    print(json.dumps(response,indent=4))
# Out:
# [
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "1005",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-01-03",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "MOBILE",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "142",
#         "last_method_description": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "last_method_begin_date": "2013-01-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": "Y",
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 177,
#         "latitude": 33.331111,
#         "longitude": -87.003611,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 163.0,
#         "probe_height": 5.0,
#         "pl_probe_location": "OTHER",
#         "local_site_name": "McAdory",
#         "address": " ROUTE 8 MCADORY",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Not in a City",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2003",
#         "parameter_code": "88101",
#         "poc": 2,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "POINT",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "142",
#         "last_method_description": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "last_method_begin_date": "2013-01-04",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 185,
#         "latitude": 33.499722,
#         "longitude": -86.924167,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 191.0,
#         "probe_height": 5.0,
#         "pl_probe_location": null,
#         "local_site_name": "Wylam",
#         "address": "1242 JERSEY ST WYLAM AL",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "6004",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2018-09-12",
#         "close_date": "2023-08-19",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "MICROSCALE",
#         "measurement_scale_def": "0 M TO 100 M",
#         "monitoring_objective": "SOURCE ORIENTED",
#         "last_method_code": "701",
#         "last_method_description": "PM2.5 SCC w/No Correction Factor - TEOM Gravimetric 50 deg C",
#         "last_method_begin_date": "2018-09-12",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 90914,
#         "latitude": 33.565278,
#         "longitude": -86.796389,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 179.0,
#         "probe_height": null,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Sloss Shuttlesworth",
#         "address": "4113 SHUTTLESWORTH DRIVE",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2003",
#         "parameter_code": "81102",
#         "poc": 2,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1994-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "208",
#         "last_method_description": "Thermo Scientific 1405-DF Dichotomous TEOM FDMS - FDMS Gravimetric",
#         "last_method_begin_date": "2019-01-10",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 185,
#         "latitude": 33.499722,
#         "longitude": -86.924167,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 191.0,
#         "probe_height": 4.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Wylam",
#         "address": "1242 JERSEY ST WYLAM AL",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "1010",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "1987-04-01",
#         "close_date": "2021-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "HIGHEST CONCENTRATION",
#         "last_method_code": "178",
#         "last_method_description": "Thermo Scientific 1405 TEOM - Gravimetric",
#         "last_method_begin_date": "2018-06-20",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 180,
#         "latitude": 33.545278,
#         "longitude": -86.549167,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 195.0,
#         "probe_height": 4.0,
#         "pl_probe_location": null,
#         "local_site_name": "Leeds",
#         "address": " 201 ASHVILLE ROAD",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Leeds",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "6002",
#         "parameter_code": "81102",
#         "poc": 3,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2011-11-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "208",
#         "last_method_description": "Thermo Scientific 1405-DF Dichotomous TEOM FDMS - FDMS Gravimetric",
#         "last_method_begin_date": "2018-03-20",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 197,
#         "latitude": 33.578333,
#         "longitude": -86.773889,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 173.0,
#         "probe_height": 5.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": "Tarrant Elementary School",
#         "address": "TARRANT, ELEM. SCH., 1269 PORTLAND STREE",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Tarrant (corporate name for Tarrant City)",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "1010",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1987-04-01",
#         "close_date": "2022-04-01",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "HIGHEST CONCENTRATION",
#         "last_method_code": "125",
#         "last_method_description": "BGI Inc. Model PQ200 PM10 - Gravimetric",
#         "last_method_begin_date": "2013-01-04",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": "Y",
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 180,
#         "latitude": 33.545278,
#         "longitude": -86.549167,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 195.0,
#         "probe_height": 4.0,
#         "pl_probe_location": null,
#         "local_site_name": "Leeds",
#         "address": " 201 ASHVILLE ROAD",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Leeds",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "5003",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2000-01-01",
#         "close_date": "2023-08-19",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "OTHER",
#         "last_method_code": "701",
#         "last_method_description": "PM2.5 SCC w/No Correction Factor - TEOM Gravimetric 50 deg C",
#         "last_method_begin_date": "2000-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 91329,
#         "latitude": 33.801667,
#         "longitude": -86.9425,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 212.0,
#         "probe_height": 5.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": "Corner",
#         "address": "10005 CORNER SCHOOL ROAD",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Not in a City",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2006",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "1999-01-03",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "MOBILE",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "701",
#         "last_method_description": "PM2.5 SCC w/No Correction Factor - TEOM Gravimetric 50 deg C",
#         "last_method_begin_date": "1999-01-03",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 188,
#         "latitude": 33.386389,
#         "longitude": -86.816667,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 180.0,
#         "probe_height": 5.0,
#         "pl_probe_location": "OTHER",
#         "local_site_name": "Hoover",
#         "address": "3425 TAMASSEE LANE, HOOVER, AL 35226",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Hoover",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "1010",
#         "parameter_code": "88101",
#         "poc": 2,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2004-01-01",
#         "close_date": "2022-04-01",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "142",
#         "last_method_description": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "last_method_begin_date": "2013-01-04",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 180,
#         "latitude": 33.545278,
#         "longitude": -86.549167,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 195.0,
#         "probe_height": 4.0,
#         "pl_probe_location": "OTHER",
#         "local_site_name": "Leeds",
#         "address": " 201 ASHVILLE ROAD",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Leeds",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2003",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "POINT",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "142",
#         "last_method_description": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "last_method_begin_date": "2013-01-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": "Y",
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 185,
#         "latitude": 33.499722,
#         "longitude": -86.924167,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 191.0,
#         "probe_height": 5.0,
#         "pl_probe_location": "OTHER",
#         "local_site_name": "Wylam",
#         "address": "1242 JERSEY ST WYLAM AL",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "6004",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1996-01-24",
#         "close_date": "2023-08-19",
#         "concurred_exclusions": null,
#         "dominant_source": "POINT",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "208",
#         "last_method_description": "Thermo Scientific 1405-DF Dichotomous TEOM FDMS - FDMS Gravimetric",
#         "last_method_begin_date": "2019-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 90914,
#         "latitude": 33.565278,
#         "longitude": -86.796389,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 179.0,
#         "probe_height": 5.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": "Sloss Shuttlesworth",
#         "address": "4113 SHUTTLESWORTH DRIVE",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "1999-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "POINT",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "HIGHEST CONCENTRATION",
#         "last_method_code": "238",
#         "last_method_description": "Teledyne T640X at 16.67 LPM - Broadband spectroscopy",
#         "last_method_begin_date": "2018-12-07",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 159,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 177.0,
#         "probe_height": 5.0,
#         "pl_probe_location": "OTHER",
#         "local_site_name": "North Birmingham",
#         "address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "1005",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "1999-01-03",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "MOBILE",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "701",
#         "last_method_description": "PM2.5 SCC w/No Correction Factor - TEOM Gravimetric 50 deg C",
#         "last_method_begin_date": "1999-01-03",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 177,
#         "latitude": 33.331111,
#         "longitude": -87.003611,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 163.0,
#         "probe_height": 5.0,
#         "pl_probe_location": "OTHER",
#         "local_site_name": "McAdory",
#         "address": " ROUTE 8 MCADORY",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Not in a City",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "1010",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2004-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "142",
#         "last_method_description": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "last_method_begin_date": "2022-07-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": "Y",
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 180,
#         "latitude": 33.545278,
#         "longitude": -86.549167,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 195.0,
#         "probe_height": 4.0,
#         "pl_probe_location": "OTHER",
#         "local_site_name": "Leeds",
#         "address": " 201 ASHVILLE ROAD",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Leeds",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "88101",
#         "poc": 23,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2018-12-07",
#         "close_date": null,
#         "concurred_exclusions": "All (2018-12-07 - 2022-11-30)",
#         "dominant_source": "POINT",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "HIGHEST CONCENTRATION; POPULATION EXPOSURE",
#         "last_method_code": "738",
#         "last_method_description": "Teledyne T640X at 16.67 LPM (Corrected) - Broadband spectroscopy",
#         "last_method_begin_date": "2018-12-07",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": "NCORE",
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 159,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 177.0,
#         "probe_height": 5.0,
#         "pl_probe_location": "OTHER",
#         "local_site_name": "North Birmingham",
#         "address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "81102",
#         "poc": 4,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1994-01-01",
#         "close_date": null,
#         "concurred_exclusions": "All (2013-02-18 - 2015-02-17)",
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "HIGHEST CONCENTRATION",
#         "last_method_code": "239",
#         "last_method_description": "Teledyne API T640X at 16.67 LPM - Broadband spectroscopy",
#         "last_method_begin_date": "2018-12-07",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": "NCORE",
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 159,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 177.0,
#         "probe_height": 4.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "North Birmingham",
#         "address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "POINT",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "HIGHEST CONCENTRATION; POPULATION EXPOSURE",
#         "last_method_code": "142",
#         "last_method_description": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "last_method_begin_date": "2013-01-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": "Y",
#         "monitor_type": "SLAMS",
#         "networks": "NCORE",
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 159,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 177.0,
#         "probe_height": 5.0,
#         "pl_probe_location": "OTHER",
#         "local_site_name": "North Birmingham",
#         "address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "88502",
#         "poc": 1,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2004-03-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "URBAN SCALE",
#         "measurement_scale_def": "4 KM TO 50 KM",
#         "monitoring_objective": "OTHER",
#         "last_method_code": "707",
#         "last_method_description": "IMPROVE Module A with Cyclone Inlet-Teflon Filter, 2.2 sq. cm. - GRAVIMETRIC",
#         "last_method_begin_date": "2004-03-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "EPA",
#         "networks": "IMPROVE",
#         "monitoring_agency_code": "0745",
#         "monitoring_agency": "National Park Service",
#         "si_id": 159,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 177.0,
#         "probe_height": null,
#         "pl_probe_location": null,
#         "local_site_name": "North Birmingham",
#         "address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "88101",
#         "poc": 3,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-01-01",
#         "close_date": null,
#         "concurred_exclusions": "All (2018-12-07 - Present)",
#         "dominant_source": "POINT",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "HIGHEST CONCENTRATION; POPULATION EXPOSURE",
#         "last_method_code": "238",
#         "last_method_description": "Teledyne T640X at 16.67 LPM - Broadband spectroscopy",
#         "last_method_begin_date": "2018-12-07",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": "NCORE",
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 159,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 177.0,
#         "probe_height": 5.0,
#         "pl_probe_location": "OTHER",
#         "local_site_name": "North Birmingham",
#         "address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "1010",
#         "parameter_code": "81102",
#         "poc": 3,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2020-07-01",
#         "close_date": "2022-04-01",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "QUALITY ASSURANCE",
#         "last_method_code": "125",
#         "last_method_description": "BGI Inc. Model PQ200 PM10 - Gravimetric",
#         "last_method_begin_date": "2020-07-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 180,
#         "latitude": 33.545278,
#         "longitude": -86.549167,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 195.0,
#         "probe_height": 4.0,
#         "pl_probe_location": null,
#         "local_site_name": "Leeds",
#         "address": " 201 ASHVILLE ROAD",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Leeds",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2003",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "1999-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "POINT",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "178",
#         "last_method_description": "Thermo Scientific 1405 TEOM - Gravimetric",
#         "last_method_begin_date": "2016-08-30",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 185,
#         "latitude": 33.499722,
#         "longitude": -86.924167,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 191.0,
#         "probe_height": 5.0,
#         "pl_probe_location": "OTHER",
#         "local_site_name": "Wylam",
#         "address": "1242 JERSEY ST WYLAM AL",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2059",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2014-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "POINT",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "OTHER",
#         "last_method_code": "142",
#         "last_method_description": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "last_method_begin_date": "2014-01-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": "NEAR ROAD",
#         "monitoring_agency_code": "0550",
#         "monitoring_agency": "Jefferson County, AL  Department Of Health",
#         "si_id": 97516,
#         "latitude": 33.521427,
#         "longitude": -86.844112,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 3.0,
#         "elevation": 183.726,
#         "probe_height": null,
#         "pl_probe_location": "POLE",
#         "local_site_name": "Arkadelphia/Near Road",
#         "address": "1110 5th Street West Birmingham, AL 35204",
#         "state_name": "Alabama",
#         "county_name": "Jefferson",
#         "city_name": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa_name": "Birmingham-Hoover, AL",
#         "csa_code": "142",
#         "csa_name": "Birmingham-Hoover-Talladega, AL",
#         "tribal_code": null,
#         "tribe_name": null
#     }
# ]

# %%
#
#    This implements the daily summary request. Daily summary provides a daily summary value for each sensor being requested
#    from the start date to the end date. 
#
#    Like the two other functions, this can be called with a mixture of a defined parameter dictionary, or with function
#    parameters. If function parameters are provided, those take precedence over any parameters from the request template.
#
def request_daily_summary(email_address = None, key = None, param=None,
                          begin_date = None, end_date = None, fips = None,
                          endpoint_url = API_REQUEST_URL, 
                          endpoint_action = API_ACTION_DAILY_SUMMARY_COUNTY, 
                          request_template = AQS_REQUEST_TEMPLATE,
                          headers = None):
    
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    if param:
        request_template['param'] = param
    if begin_date:
        request_template['begin_date'] = begin_date
    if end_date:
        request_template['end_date'] = end_date
    if fips and len(fips)==5:
        request_template['state'] = fips[:2]
        request_template['county'] = fips[2:]            

    # Make sure there are values that allow us to make a call - these are always required
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_daily_summary()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_daily_summary()'")
    if not request_template['param']: 
        raise Exception("Must supply param values to call 'request_daily_summary()'")
    if not request_template['begin_date']: 
        raise Exception("Must supply a begin_date to call 'request_daily_summary()'")
    if not request_template['end_date']: 
        raise Exception("Must supply an end_date to call 'request_daily_summary()'")
    # Note we're not validating FIPS fields because not all of the daily summary actions require the FIPS numbers
        
    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
        
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_GASEOUS

bbox = bounding_latlon(CITY_LOCATIONS['birmingham'],scale=1.0)
#   put our bounding box into the request_data
request_data['minlat'] = bbox[0]
request_data['maxlat'] = bbox[1]
request_data['minlon'] = bbox[2]
request_data['maxlon'] = bbox[3]

request_data['state'] = CITY_LOCATIONS['birmingham']['fips'][:2]   # the first two digits (characters) of FIPS is the state code
request_data['county'] = CITY_LOCATIONS['birmingham']['fips'][2:]  # the last three digits (characters) of FIPS is the county code

# request daily summary data for the month of July in 2021
gaseous_aqi = request_daily_summary(request_template=request_data, begin_date="20210701", end_date="20210731")
print("Response for the gaseous pollutants ...")
#
if gaseous_aqi["Header"][0]['status'] == "Success":
    print(json.dumps(gaseous_aqi['Data'],indent=4))
elif gaseous_aqi["Header"][0]['status'].startswith("No data "):
    print("Looks like the response generated no data. You might take a closer look at your request and the response data.")
else:
    print(json.dumps(gaseous_aqi,indent=4))

request_data['param'] = AQI_PARAMS_PARTICULATES
# request daily summary data for the month of July in 2021
particulate_aqi = request_daily_summary(request_template=request_data, begin_date="20210701", end_date="20210731")
print("Response for the particulate pollutants ...")
#
if particulate_aqi["Header"][0]['status'] == "Success":
    print(json.dumps(particulate_aqi['Data'],indent=4))
elif particulate_aqi["Header"][0]['status'].startswith("No data "):
    print("Looks like the response generated no data. You might take a closer look at your request and the response data.")
else:
    print(json.dumps(particulate_aqi,indent=4))
# Out:
# Response for the gaseous pollutants ...
# [
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-04",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.025583,
#         "first_max_value": 0.056,
#         "first_max_hour": 13,
#         "aqi": null,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-01",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.015458,
#         "first_max_value": 0.029,
#         "first_max_hour": 13,
#         "aqi": null,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-02",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.018083,
#         "first_max_value": 0.034,
#         "first_max_hour": 14,
#         "aqi": null,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-03",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.0255,
#         "first_max_value": 0.047,
#         "first_max_hour": 15,
#         "aqi": null,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-01",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.016042,
#         "first_max_value": 0.025,
#         "first_max_hour": 9,
#         "aqi": 23,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 2008",
#         "date_local": "2021-07-01",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.016042,
#         "first_max_value": 0.025,
#         "first_max_hour": 9,
#         "aqi": 23,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 2008",
#         "date_local": "2021-07-02",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.016833,
#         "first_max_value": 0.029,
#         "first_max_hour": 10,
#         "aqi": 27,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 2008",
#         "date_local": "2021-07-03",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.024167,
#         "first_max_value": 0.044,
#         "first_max_hour": 10,
#         "aqi": 41,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-hour 2015",
#         "date_local": "2021-07-01",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 17,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.016765,
#         "first_max_value": 0.025,
#         "first_max_hour": 9,
#         "aqi": 23,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-hour 2015",
#         "date_local": "2021-07-02",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 17,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.017,
#         "first_max_value": 0.029,
#         "first_max_hour": 10,
#         "aqi": 27,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-hour 2015",
#         "date_local": "2021-07-03",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 17,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.026294,
#         "first_max_value": 0.044,
#         "first_max_hour": 10,
#         "aqi": 41,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-02",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.016833,
#         "first_max_value": 0.029,
#         "first_max_hour": 10,
#         "aqi": 27,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-03",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.024167,
#         "first_max_value": 0.044,
#         "first_max_hour": 10,
#         "aqi": 41,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-04",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.02525,
#         "first_max_value": 0.049,
#         "first_max_hour": 10,
#         "aqi": 45,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 2008",
#         "date_local": "2021-07-04",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.02525,
#         "first_max_value": 0.049,
#         "first_max_hour": 10,
#         "aqi": 45,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-hour 2015",
#         "date_local": "2021-07-04",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 17,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.027294,
#         "first_max_value": 0.049,
#         "first_max_hour": 10,
#         "aqi": 45,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-05",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.026208,
#         "first_max_value": 0.049,
#         "first_max_hour": 17,
#         "aqi": null,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-05",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.025458,
#         "first_max_value": 0.046,
#         "first_max_hour": 10,
#         "aqi": 43,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 2008",
#         "date_local": "2021-07-05",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.025458,
#         "first_max_value": 0.046,
#         "first_max_hour": 10,
#         "aqi": 43,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-hour 2015",
#         "date_local": "2021-07-05",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 17,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.025824,
#         "first_max_value": 0.046,
#         "first_max_hour": 10,
#         "aqi": 43,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-06",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.015333,
#         "first_max_value": 0.026,
#         "first_max_hour": 15,
#         "aqi": null,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-06",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.016792,
#         "first_max_value": 0.022,
#         "first_max_hour": 9,
#         "aqi": 20,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 2008",
#         "date_local": "2021-07-06",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.016792,
#         "first_max_value": 0.022,
#         "first_max_hour": 9,
#         "aqi": 20,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-hour 2015",
#         "date_local": "2021-07-06",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 17,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.018824,
#         "first_max_value": 0.022,
#         "first_max_hour": 9,
#         "aqi": 20,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-07",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.016083,
#         "first_max_value": 0.026,
#         "first_max_hour": 14,
#         "aqi": null,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-07",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.014083,
#         "first_max_value": 0.022,
#         "first_max_hour": 11,
#         "aqi": 20,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 2008",
#         "date_local": "2021-07-07",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.014083,
#         "first_max_value": 0.022,
#         "first_max_hour": 11,
#         "aqi": 20,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-hour 2015",
#         "date_local": "2021-07-07",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 17,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.014412,
#         "first_max_value": 0.022,
#         "first_max_hour": 11,
#         "aqi": 20,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-08",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.018417,
#         "first_max_value": 0.032,
#         "first_max_hour": 10,
#         "aqi": null,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-08",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.018833,
#         "first_max_value": 0.029,
#         "first_max_hour": 8,
#         "aqi": 27,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 2008",
#         "date_local": "2021-07-08",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.018833,
#         "first_max_value": 0.029,
#         "first_max_hour": 8,
#         "aqi": 27,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-hour 2015",
#         "date_local": "2021-07-08",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 17,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.020235,
#         "first_max_value": 0.029,
#         "first_max_hour": 8,
#         "aqi": 27,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-09",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.017,
#         "first_max_value": 0.026,
#         "first_max_hour": 18,
#         "aqi": null,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-09",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.016292,
#         "first_max_value": 0.023,
#         "first_max_hour": 12,
#         "aqi": 21,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 2008",
#         "date_local": "2021-07-09",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.016292,
#         "first_max_value": 0.023,
#         "first_max_hour": 12,
#         "aqi": 21,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-hour 2015",
#         "date_local": "2021-07-09",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 17,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.017471,
#         "first_max_value": 0.023,
#         "first_max_hour": 12,
#         "aqi": 21,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-10",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.017583,
#         "first_max_value": 0.028,
#         "first_max_hour": 15,
#         "aqi": null,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-10",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.017542,
#         "first_max_value": 0.025,
#         "first_max_hour": 9,
#         "aqi": 23,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 2008",
#         "date_local": "2021-07-10",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.017542,
#         "first_max_value": 0.025,
#         "first_max_hour": 9,
#         "aqi": 23,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-hour 2015",
#         "date_local": "2021-07-10",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 17,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.018471,
#         "first_max_value": 0.025,
#         "first_max_hour": 9,
#         "aqi": 23,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-11",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.015042,
#         "first_max_value": 0.019,
#         "first_max_hour": 10,
#         "aqi": null,
#         "method_code": "087",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "local_site_name": "North Birmingham",
#         "site_address": "NO. B'HAM,SOU R.R., 3009 28TH ST. NO.",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "0023",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 33.553056,
#         "longitude": -86.815,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
# ...
#         "validity_indicator": "Y",
#         "arithmetic_mean": 6.8,
#         "first_max_value": 6.8,
#         "first_max_hour": 0,
#         "aqi": 38,
#         "method_code": "142",
#         "method": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "local_site_name": "Wylam",
#         "site_address": "1242 JERSEY ST WYLAM AL",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-17"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2003",
#         "parameter_code": "88101",
#         "poc": 2,
#         "latitude": 33.499722,
#         "longitude": -86.924167,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-15",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 11.9,
#         "first_max_value": 11.9,
#         "first_max_hour": 0,
#         "aqi": 56,
#         "method_code": "142",
#         "method": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "local_site_name": "Wylam",
#         "site_address": "1242 JERSEY ST WYLAM AL",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-17"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2003",
#         "parameter_code": "88101",
#         "poc": 2,
#         "latitude": 33.499722,
#         "longitude": -86.924167,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-21",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 5.6,
#         "first_max_value": 5.6,
#         "first_max_hour": 0,
#         "aqi": 31,
#         "method_code": "142",
#         "method": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "local_site_name": "Wylam",
#         "site_address": "1242 JERSEY ST WYLAM AL",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-17"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2003",
#         "parameter_code": "88101",
#         "poc": 2,
#         "latitude": 33.499722,
#         "longitude": -86.924167,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-27",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 10.3,
#         "first_max_value": 10.3,
#         "first_max_hour": 0,
#         "aqi": 53,
#         "method_code": "142",
#         "method": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "local_site_name": "Wylam",
#         "site_address": "1242 JERSEY ST WYLAM AL",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-17"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2059",
#         "parameter_code": "88101",
#         "poc": 1,
#         "latitude": 33.521427,
#         "longitude": -86.844112,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-03",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 10.1,
#         "first_max_value": 10.1,
#         "first_max_hour": 0,
#         "aqi": 53,
#         "method_code": "142",
#         "method": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "local_site_name": "Arkadelphia/Near Road",
#         "site_address": "1110 5th Street West Birmingham, AL 35204",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-17"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2059",
#         "parameter_code": "88101",
#         "poc": 1,
#         "latitude": 33.521427,
#         "longitude": -86.844112,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-07",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 6.5,
#         "first_max_value": 6.5,
#         "first_max_hour": 0,
#         "aqi": 36,
#         "method_code": "142",
#         "method": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "local_site_name": "Arkadelphia/Near Road",
#         "site_address": "1110 5th Street West Birmingham, AL 35204",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-17"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2059",
#         "parameter_code": "88101",
#         "poc": 1,
#         "latitude": 33.521427,
#         "longitude": -86.844112,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-09",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 7.1,
#         "first_max_value": 7.1,
#         "first_max_hour": 0,
#         "aqi": 39,
#         "method_code": "142",
#         "method": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "local_site_name": "Arkadelphia/Near Road",
#         "site_address": "1110 5th Street West Birmingham, AL 35204",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-17"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2059",
#         "parameter_code": "88101",
#         "poc": 1,
#         "latitude": 33.521427,
#         "longitude": -86.844112,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-13",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 8.8,
#         "first_max_value": 8.8,
#         "first_max_hour": 0,
#         "aqi": 49,
#         "method_code": "142",
#         "method": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "local_site_name": "Arkadelphia/Near Road",
#         "site_address": "1110 5th Street West Birmingham, AL 35204",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-17"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2059",
#         "parameter_code": "88101",
#         "poc": 1,
#         "latitude": 33.521427,
#         "longitude": -86.844112,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-15",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 11.7,
#         "first_max_value": 11.7,
#         "first_max_hour": 0,
#         "aqi": 56,
#         "method_code": "142",
#         "method": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "local_site_name": "Arkadelphia/Near Road",
#         "site_address": "1110 5th Street West Birmingham, AL 35204",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-17"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2059",
#         "parameter_code": "88101",
#         "poc": 1,
#         "latitude": 33.521427,
#         "longitude": -86.844112,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-18",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 5.8,
#         "first_max_value": 5.8,
#         "first_max_hour": 0,
#         "aqi": 32,
#         "method_code": "142",
#         "method": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "local_site_name": "Arkadelphia/Near Road",
#         "site_address": "1110 5th Street West Birmingham, AL 35204",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-17"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2059",
#         "parameter_code": "88101",
#         "poc": 1,
#         "latitude": 33.521427,
#         "longitude": -86.844112,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-21",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 6.3,
#         "first_max_value": 6.3,
#         "first_max_hour": 0,
#         "aqi": 35,
#         "method_code": "142",
#         "method": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "local_site_name": "Arkadelphia/Near Road",
#         "site_address": "1110 5th Street West Birmingham, AL 35204",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-17"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2059",
#         "parameter_code": "88101",
#         "poc": 1,
#         "latitude": 33.521427,
#         "longitude": -86.844112,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-24",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 14.4,
#         "first_max_value": 14.4,
#         "first_max_hour": 0,
#         "aqi": 61,
#         "method_code": "142",
#         "method": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "local_site_name": "Arkadelphia/Near Road",
#         "site_address": "1110 5th Street West Birmingham, AL 35204",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-17"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2059",
#         "parameter_code": "88101",
#         "poc": 1,
#         "latitude": 33.521427,
#         "longitude": -86.844112,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-27",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 11.6,
#         "first_max_value": 11.6,
#         "first_max_hour": 0,
#         "aqi": 56,
#         "method_code": "142",
#         "method": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "local_site_name": "Arkadelphia/Near Road",
#         "site_address": "1110 5th Street West Birmingham, AL 35204",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-17"
#     },
#     {
#         "state_code": "01",
#         "county_code": "073",
#         "site_number": "2059",
#         "parameter_code": "88101",
#         "poc": 1,
#         "latitude": 33.521427,
#         "longitude": -86.844112,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-30",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 18.0,
#         "first_max_value": 18.0,
#         "first_max_hour": 0,
#         "aqi": 68,
#         "method_code": "142",
#         "method": "BGI Models PQ200-VSCC or PQ200A-VSCC - Gravimetric",
#         "local_site_name": "Arkadelphia/Near Road",
#         "site_address": "1110 5th Street West Birmingham, AL 35204",
#         "state": "Alabama",
#         "county": "Jefferson",
#         "city": "Birmingham",
#         "cbsa_code": "13820",
#         "cbsa": "Birmingham-Hoover, AL",
#         "date_of_last_change": "2024-05-17"
#     }
# ]

# %%
# This function extracts the data from the API and store them in a dataframe
def extract_aqs_table(aqs_data):
    if aqs_data['Header'][0]['status'] == 'Success':
        data = pd.DataFrame(aqs_data['Data'])
    elif aqs_data['Header'][0]['status'].startswith('No data'):
        data = pd.DataFrame()
    else:
        data = aqs_data['Header'][0]['status']
    return data

# %%
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY

request_data['state'] = CITY_LOCATIONS['birmingham']['fips'][:2]   
request_data['county'] = CITY_LOCATIONS['birmingham']['fips'][2:]

# Define paths to save the data
gaseous_file_path = 'intermediate-data/gaseous_aqi_data.csv'
particulate_file_path = 'intermediate-data/particulate_aqi_data.csv'

# Initialize the DataFrames
gaseous_df = pd.DataFrame()
particulate_df = pd.DataFrame()

for year in range(STARTYEAR, ENDYEAR + 1):
    
    print(f'Pulling year {year}')
    start_date = str(year) + '0101'
    end_date = str(year) + '1231'

    # request daily summary data for gasses
    request_data['param'] = AQI_PARAMS_GASEOUS
    gaseous_aqi = request_daily_summary(request_template=request_data,
                                        begin_date=start_date, end_date=end_date)

    # request daily summary data for particulates
    request_data['param'] = AQI_PARAMS_PARTICULATES
    particulate_aqi = request_daily_summary(request_template=request_data,
                                            begin_date=start_date, end_date=end_date)
    
    # Extract dataframes
    gaseous_extract = extract_aqs_table(gaseous_aqi)
    particulate_extract = extract_aqs_table(particulate_aqi)
    
    # Check for unusual API statuses, break the loop if an unusual status pops up
    if isinstance(gaseous_extract, str):
        print(gaseous_extract)
        break
    else:
        gaseous_df = pd.concat([gaseous_df, gaseous_extract])
        
    if isinstance(particulate_extract, str):
        print(particulate_extract)
        break
    else:
        particulate_df = pd.concat([particulate_df, particulate_extract])

    # Save the data for the current year to CSV (appending to existing file)
    # If it's the first year, write the header; otherwise, append without header.
    gaseous_df.to_csv(gaseous_file_path, mode='a', header=not os.path.exists(gaseous_file_path), index=False)
    particulate_df.to_csv(particulate_file_path, mode='a', header=not os.path.exists(particulate_file_path), index=False)

    # Clear the DataFrame after saving to prevent data duplication in future iterations
    gaseous_df = pd.DataFrame()
    particulate_df = pd.DataFrame()

    print(f'Data for year {year} saved successfully.')

print("All data saved successfully.")
# Out:
# Pulling year 1961
# Data for year 1961 saved successfully.
# Pulling year 1962
# Data for year 1962 saved successfully.
# Pulling year 1963
# Data for year 1963 saved successfully.
# Pulling year 1964
# Data for year 1964 saved successfully.
# Pulling year 1965
# Data for year 1965 saved successfully.
# Pulling year 1966
# Data for year 1966 saved successfully.
# Pulling year 1967
# Data for year 1967 saved successfully.
# Pulling year 1968
# Data for year 1968 saved successfully.
# Pulling year 1969
# Data for year 1969 saved successfully.
# Pulling year 1970
# Data for year 1970 saved successfully.
# Pulling year 1971
# Data for year 1971 saved successfully.
# Pulling year 1972
# Data for year 1972 saved successfully.
# Pulling year 1973
# Data for year 1973 saved successfully.
# Pulling year 1974
# Data for year 1974 saved successfully.
# Pulling year 1975
# Data for year 1975 saved successfully.
# Pulling year 1976
# Data for year 1976 saved successfully.
# Pulling year 1977
# Data for year 1977 saved successfully.
# Pulling year 1978
# Data for year 1978 saved successfully.
# Pulling year 1979
# Data for year 1979 saved successfully.
# Pulling year 1980
# Data for year 1980 saved successfully.
# Pulling year 1981
# Data for year 1981 saved successfully.
# Pulling year 1982
# Data for year 1982 saved successfully.
# Pulling year 1983
# Data for year 1983 saved successfully.
# Pulling year 1984
# Data for year 1984 saved successfully.
# Pulling year 1985
# Data for year 1985 saved successfully.
# Pulling year 1986
# Data for year 1986 saved successfully.
# Pulling year 1987
# Data for year 1987 saved successfully.
# Pulling year 1988
# Data for year 1988 saved successfully.
# Pulling year 1989
# Data for year 1989 saved successfully.
# Pulling year 1990
# Data for year 1990 saved successfully.
# Pulling year 1991
# Data for year 1991 saved successfully.
# Pulling year 1992
# Data for year 1992 saved successfully.
# Pulling year 1993
# Data for year 1993 saved successfully.
# Pulling year 1994
# Data for year 1994 saved successfully.
# Pulling year 1995
# Data for year 1995 saved successfully.
# Pulling year 1996
# Data for year 1996 saved successfully.
# Pulling year 1997
# Data for year 1997 saved successfully.
# Pulling year 1998
# Data for year 1998 saved successfully.
# Pulling year 1999
# Data for year 1999 saved successfully.
# Pulling year 2000
# Data for year 2000 saved successfully.
# Pulling year 2001
# Data for year 2001 saved successfully.
# Pulling year 2002
# Data for year 2002 saved successfully.
# Pulling year 2003
# Data for year 2003 saved successfully.
# Pulling year 2004
# Data for year 2004 saved successfully.
# Pulling year 2005
# Data for year 2005 saved successfully.
# Pulling year 2006
# Data for year 2006 saved successfully.
# Pulling year 2007
# Data for year 2007 saved successfully.
# Pulling year 2008
# Data for year 2008 saved successfully.
# Pulling year 2009
# Data for year 2009 saved successfully.
# Pulling year 2010
# Data for year 2010 saved successfully.
# Pulling year 2011
# Data for year 2011 saved successfully.
# Pulling year 2012
# Data for year 2012 saved successfully.
# Pulling year 2013
# Data for year 2013 saved successfully.
# Pulling year 2014
# Data for year 2014 saved successfully.
# Pulling year 2015
# Data for year 2015 saved successfully.
# Pulling year 2016
# Data for year 2016 saved successfully.
# Pulling year 2017
# Data for year 2017 saved successfully.
# Pulling year 2018
# Data for year 2018 saved successfully.
# Pulling year 2019
# Data for year 2019 saved successfully.
# Pulling year 2020
# Data for year 2020 saved successfully.
# Pulling year 2021
# Data for year 2021 saved successfully.
# All data saved successfully.
